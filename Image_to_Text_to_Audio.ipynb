# %% [markdown]
# <a href="https://colab.research.google.com/github/NoobCoder6969/Image-to-Text-to-Audio/blob/main/Image_to_Text_to_Audio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Image to Text to Audio
# This notebook demonstrates how to extract text from an image and convert it into an audio file using Tesseract OCR and Google Text-to-Speech (gTTS). The notebook includes the following steps:

# %% [markdown]
# ### 1. Install Dependencies

# %%
# !sudo apt install tesseract-ocr &> /dev/null
# !pip install pytesseract gTTS Pillow==9.0.0 &> /dev/null

# %% [markdown]
# ### 2. Import the libraries

# %%
import pytesseract # For OCR (Optical Character Recognition)
from PIL import Image # For handling image files
import gtts # For converting text to speech
from IPython.display import Audio, display # For playing audio in colab

# %%
img = Image.open('/content/Image.png')
print(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1272x371 at 0x7A0ED175DA80>

# %%
result = pytesseract.image_to_string(img)
print(result)
# Out:
# We can't have a research topic that's based on only one person's opinion
#
# Are there enough sources?
# Are we going to do some valuable contribution to the subject
#
# -Avoid recent topics
# -Avoid topics with ample knowledge
#
# -Make sure there are plenty of sources (make sure it does not require research on only one source)
# -Make sure it's not based on only one person's opinion
#
# -Avoid controversial topics
# -Should lead to defensible conclusions

# %%
display(Audio('Audio.mp3'))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
